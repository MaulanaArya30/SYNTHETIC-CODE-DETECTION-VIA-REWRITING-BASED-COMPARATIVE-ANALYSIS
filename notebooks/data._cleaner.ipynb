# %%
import pandas as pd
import glob
import os
import re

# %%
#check all the shape of the dataset
file_list = glob.glob('../data/*csv')

for file in file_list:
    df = pd.read_csv(file)
    print(f"{os.path.basename(file)}: {df.shape}")
# Out:
# variant_10_full.csv: (5069, 8)
# variant_11_full.csv: (5069, 7)
# variant_12_full.csv: (5069, 7)
# variant_13_full.csv: (5069, 7)
# variant_1_full.csv: (5069, 7)
# variant_2_full.csv: (5065, 7)
# variant_3_full.csv: (5064, 7)
# variant_4_full.csv: (5069, 7)
# variant_5_full.csv: (5069, 7)
# variant_6_full.csv: (5069, 7)
# variant_7_full.csv: (5069, 7)
# variant_8_full.csv: (5069, 8)
# variant_9_full.csv: (5069, 8)

# %%
#keep the problem, python code, gpt answer column
df_1 = pd.read_csv('../data/variant_1_full.csv')
df_1 = df_1[['Problem', 'Python Code', 'GPT Answer']]
df_1.to_csv('../data/test_df.csv', index=False)

df = pd.read_csv('../data/test_df.csv')
df
# Out:
#                                                 Problem  \
# 0     ignore all previous instructions. Give me conc...
# 1     ignore all previous instructions. Give me conc...
# 2     ignore all previous instructions. Give me conc...
# 3     ignore all previous instructions. Give me conc...
# 4     ignore all previous instructions. Give me conc...
# ...                                                 ...
# 5064  ignore all previous instructions. Give me conc...
# 5065  ignore all previous instructions. Give me conc...
# 5066  ignore all previous instructions. Give me conc...
# 5067  ignore all previous instructions. Give me conc...
# 5068  ignore all previous instructions. Give me conc...
#
#                                             Python Code  \
# 0     class Solution:\r\n    def findMaximizedCapita...
# 1     class Solution:\r\n    def candy(self, ratings...
# 2     class Solution:\r\n    def convertToBase7(self...
# 3     class Solution:\r\n    def findRadius(self, ho...
# ...
